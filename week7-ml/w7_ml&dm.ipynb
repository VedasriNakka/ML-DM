# %% [markdown]
# ## Week 7: Machine Learning & Data Mining

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %% [markdown]
# ### Q1. Predicting the class ‘Survived’ with Decision tree, KNN, Na¨ıve Bayes classifiers.

# %%
# loading Titanic data

titanic = pd.read_csv('./titanic.csv')
print("Number of points in original data: {}".format(len(titanic.index)))

columns = titanic.columns
print("Features present in dataset: \n", list(columns))
titanic.head(5)
# Out:
# Number of points in original data: 887
# Features present in dataset:
#  ['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Siblings/Spouses Aboard', 'Parents/Children Aboard', 'Fare']
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %% [markdown]
# #### Converting continuous attaribute into classes

# %%
conditions = [(titanic['Age'] < 25.0),(titanic['Age'] > 45.0), 
              (titanic['Age'] > 25.0) & (titanic['Age'] < 45.0)]

values = [1, 3, 2]
titanic['New_age'] = np.select(conditions, values)
#titanic
conditions = [(titanic['Fare'] < 15),(titanic['Fare'] > 50), 
              (titanic['Fare'] > 15) & (titanic['Fare'] < 50)]

values = [1, 3, 2]
titanic['New_Fare'] = np.select(conditions, values)

#titanic.loc[titanic['Siblings/Spouses Aboard'] == 1 , 'Siblings/Spouses Aboard'] = 'True'
#titanic

titanic.loc[titanic['Sex'] == 'male', 'Sex'] = 1
titanic.loc[titanic['Sex'] == 'female', 'Sex'] = 0

# %% [markdown]
# #### Removing continuous attributes after creating new attribute of same column

# %%
titanic.drop(columns=['Age','Fare'], axis = 1, inplace = True)
titanic
# Out:
#      Survived  Pclass                                               Name Sex  \
# 0           0       3                             Mr. Owen Harris Braund   1
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...   0
# 2           1       3                              Miss. Laina Heikkinen   0
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle   0
# 4           0       3                            Mr. William Henry Allen   1
# ..        ...     ...                                                ...  ..
# 882         0       2                               Rev. Juozas Montvila   1
# 883         1       1                        Miss. Margaret Edith Graham   0
# 884         0       3                     Miss. Catherine Helen Johnston   0
# 885         1       1                               Mr. Karl Howell Behr   1
# 886         0       3                                 Mr. Patrick Dooley   1
#
#      Siblings/Spouses Aboard  Parents/Children Aboard  New_age  New_Fare
# 0                          1                        0        1         1
# 1                          1                        0        2         3
# 2                          0                        0        2         1
# 3                          1                        0        2         3
# 4                          0                        0        2         1
# ..                       ...                      ...      ...       ...
# 882                        0                        0        2         1
# 883                        0                        0        1         2
# 884                        1                        2        1         2
# 885                        0                        0        2         2
# 886                        0                        0        2         1
#
# [887 rows x 8 columns]

# %%
le = preprocessing.LabelEncoder()

pd.set_option('display.max_colwidth', None)
x = titanic[["Pclass","Sex","Siblings/Spouses Aboard","Parents/Children Aboard", "New_age","New_Fare"]]
y = le.fit(titanic["Survived"])
y = le.transform(titanic["Survived"])


# set the random state 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.35, random_state=0)

print("No of training samples: {}".format(x_train.shape))
print("No of test samples    : {}".format(x_test.shape))
print("y training samples    : {}".format(y_train.shape))
print("y test samples        : {}".format(y_test.shape))
x_train.head(5)
# Out:
# No of training samples: (576, 6)
# No of test samples    : (311, 6)
# y training samples    : (576,)
# y test samples        : (311,)
#      Pclass Sex  Siblings/Spouses Aboard  Parents/Children Aboard  New_age  \
# 243       3   1                        0                        0        2
# 518       3   1                        0                        0        1
# 35        1   1                        1                        0        2
# 81        3   0                        0                        0        2
# 159       3   1                        0                        1        2
#
#      New_Fare
# 243         1
# 518         1
# 35          3
# 81          1
# 159         2

# %% [markdown]
# #### a. Accuracy of the classifies with 5-fold CV

# %%
from sklearn.model_selection import KFold
from sklearn.tree import DecisionTreeClassifier

k = 5
dt_kfold = KFold(n_splits = k, random_state = None)
dt_model = DecisionTreeClassifier()
dt_acc_score = []
#print(x_train.shape)
dt_precision = []
dt_recall = []
dt_f1 = []

for train_index, test_index in dt_kfold.split(x):
    #print(train_index.shape, test_index.shape)
    dt_x_train, dt_x_test = x.iloc[train_index,:], x.iloc[test_index,:]
    dt_y_train, dt_y_test = y[train_index], y[test_index]
    
    dt_model.fit(dt_x_train,dt_y_train)
    dt_predict = dt_model.predict(dt_x_test)
    dt_acc = accuracy_score(dt_predict, dt_y_test)
    dt_acc_score.append(dt_acc)
    
    precision_tree = precision_score(dt_y_test, dt_predict)
    dt_precision.append(precision_tree)
    
    recall_tree = recall_score(dt_y_test, dt_predict)
    dt_recall.append(recall_tree)
    
    f1_tree = f1_score(dt_y_test, dt_predict)
    dt_f1.append(f1_tree)

avg_dt_acc_score = sum(dt_acc_score)/k
print("Accuracy of decision tree of each fold is:\n {}".format(dt_acc_score))
print("Average accuracy of decision tree is {:.2f}%".format(100*avg_dt_acc_score))
# Out:
# Accuracy of decision tree of each fold is:
#  [0.7752808988764045, 0.7921348314606742, 0.807909604519774, 0.768361581920904, 0.8248587570621468]
# Average accuracy of decision tree is 79.37%

# %% [markdown]
# #### Precision, recall, f1 of decion tree classifier

# %%
avg_dt_precision = sum(dt_precision)/k
print("Precision of decision tree of each fold is:\n{}".format(dt_precision))
print("precision accuracy of decision tree is:    {:.2f}% \n".format(100*avg_dt_precision))

avg_dt_recall = sum(dt_recall)/k
print("Recall of decision tree of each fold is:\n{}".format(dt_recall))
print("Recall accuracy of decision tree is:       {:.2f}% \n".format(100*avg_dt_recall))

avg_dt_f1 = sum(dt_f1)/k
print("F1 of decision tree of each fold is:\n{} ".format(dt_f1))
print("F1 accuracy of decision tree is:           {:.2f}% \n".format(100*avg_dt_f1))
# Out:
# Precision of decision tree of each fold is:
# [0.6727272727272727, 0.8088235294117647, 0.78125, 0.7586206896551724, 0.7758620689655172]
# precision accuracy of decision tree is:    75.95%
#
# Recall of decision tree of each fold is:
# [0.6271186440677966, 0.6962025316455697, 0.7142857142857143, 0.6197183098591549, 0.7142857142857143]
# Recall accuracy of decision tree is:       67.43%
#
# F1 of decision tree of each fold is:
# [0.6491228070175439, 0.7482993197278912, 0.7462686567164178, 0.6821705426356589, 0.7438016528925621]
# F1 accuracy of decision tree is:           71.39%

# %% [markdown]
# #### Finding accuracy of K-fold, precision, recall and f1-score of KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

k = 5
knn_kfold = KFold(n_splits = k, random_state = None)
knn_model = KNeighborsClassifier()
knn_acc_score = []
#print(x_train.shape)
knn_precision = []
knn_recall = []
knn_f1 = []

for train_index_knn, test_index_knn in knn_kfold.split(x):
    #print(train_index.shape, test_index.shape)
    knn_x_train, knn_x_test = x.iloc[train_index_knn,:], x.iloc[test_index_knn,:]
    knn_y_train, knn_y_test = y[train_index_knn], y[test_index_knn]
    
    knn_model.fit(knn_x_train,knn_y_train)
    knn_predict = knn_model.predict(knn_x_test)
    knn_acc = accuracy_score(knn_predict, knn_y_test)
    knn_acc_score.append(knn_acc)
    
    precision_knn = precision_score(knn_y_test, knn_predict)
    knn_precision.append(precision_knn)
    
    recall_knn = recall_score(knn_y_test, knn_predict)
    knn_recall.append(recall_knn)
    
    f1_knn = f1_score(knn_y_test, knn_predict)
    knn_f1.append(f1_knn)

avg_knn_acc_score = sum(knn_acc_score)/k
print("Accuracy of KNN of each fold is:\n{}".format(knn_acc_score))
print("Average accuracy of knn is:       {:.2f}%".format(100*avg_knn_acc_score))
# Out:
# Accuracy of KNN of each fold is:
# [0.7528089887640449, 0.7921348314606742, 0.8022598870056498, 0.7966101694915254, 0.8305084745762712]
# Average accuracy of knn is:       79.49%

# %%
avg_knn_precision = sum(knn_precision)/k
print("Precision of KNN of each fold is:\n{}".format(knn_precision))
print("precision accuracy of KNN is:    {:.2f}% \n".format(100*avg_knn_precision))

avg_knn_recall = sum(knn_recall)/k
print("Recall of KNN of each fold is:\n{}".format(knn_recall))
print("Recall accuracy of KNN is:       {:.2f}% \n".format(100*avg_knn_recall))

avg_knn_f1 = sum(knn_f1)/k
print("F1 of KNN of each fold is:\n{} ".format(knn_f1))
print("F1 accuracy of KNN is:           {:.2f}% \n".format(100*avg_knn_f1))
# Out:
# Precision of KNN of each fold is:
# [0.6119402985074627, 0.7763157894736842, 0.7536231884057971, 0.8571428571428571, 0.8666666666666667]
# precision accuracy of KNN is:    77.31%
#
# Recall of KNN of each fold is:
# [0.6949152542372882, 0.7468354430379747, 0.7428571428571429, 0.5915492957746479, 0.6190476190476191]
# Recall accuracy of KNN is:       67.90%
#
# F1 of KNN of each fold is:
# [0.6507936507936508, 0.7612903225806452, 0.748201438848921, 0.7000000000000001, 0.7222222222222222]
# F1 accuracy of KNN is:           71.65%

# %% [markdown]
# #### After calculated KNN classifier by direct devide the data into training and test got accuracy 79.10% and by deviding the training data into 5 folds got an average accuracy of 79.49% I observed that both accuracies are almost same.

# %%
knnclassifier = KNeighborsClassifier(n_neighbors = 3, metric = 'cosine')
knnclassifier.fit(x_train.values, y_train)
knn_y_pred = knnclassifier.predict(x_test.values)

knn_acc = accuracy_score(y_test, knn_y_pred)
print("KNN Accuracy   : {:.2f}%".format(100*knn_acc))

knn_precision = precision_score(y_test, knn_y_pred)
print("KNN precision  : {:.2f}%".format(100*knn_precision))

knn_recall = recall_score(y_test, knn_y_pred)
print("KNN Accuracy   : {:.2f}%".format(100*knn_recall))

knn_f1 = f1_score(y_test, knn_y_pred)
print("KNN Accuracy   : {:.2f}%".format(100*knn_f1))

print("KNN confusion_matrix :\n{}".format(confusion_matrix(y_test,knn_y_pred)))

KNN_report = classification_report(y_test, knn_y_pred)
print(KNN_report)
# Out:
# KNN Accuracy   : 79.10%
# KNN precision  : 75.00%
# KNN Accuracy   : 69.42%
# KNN Accuracy   : 72.10%
# KNN confusion_matrix :
# [[162  28]
#  [ 37  84]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83       190
#            1       0.75      0.69      0.72       121
#
#     accuracy                           0.79       311
#    macro avg       0.78      0.77      0.78       311
# weighted avg       0.79      0.79      0.79       311

# %% [markdown]
# #### Finding accuracy of K-fold, precision, recall and f1-score of Naive bays classifier

# %%
from sklearn.naive_bayes import GaussianNB

k = 5
g_kfold = KFold(n_splits = k, random_state = None)
g_model = GaussianNB()
g_acc_score = []
#print(x_train.shape)
g_precision = []
g_recall = []
g_f1 = []

for train_index_g, test_index_g in g_kfold.split(x):
    #print(train_index.shape, test_index.shape)
    g_x_train, g_x_test = x.iloc[train_index_g,:], x.iloc[test_index_g,:]
    g_y_train, g_y_test = y[train_index_g], y[test_index_g]
    
    g_model.fit(g_x_train,g_y_train)
    g_predict = g_model.predict(g_x_test)
    g_acc = accuracy_score(g_predict, g_y_test)
    g_acc_score.append(g_acc)
    
    precision_g = precision_score(g_y_test, g_predict)
    g_precision.append(precision_g)
    
    recall_g = recall_score(g_y_test, g_predict)
    g_recall.append(recall_g)
    
    f1_g = f1_score(g_y_test, g_predict)
    g_f1.append(f1_g)

avg_g_acc_score = sum(g_acc_score)/k
print("Accuracy of Gaussian of each fold is:\n{}".format(g_acc_score))
print("Average accuracy of Gaussian is:       {:.2f}%".format(100*avg_g_acc_score))
# Out:
# Accuracy of Gaussian of each fold is:
# [0.7134831460674157, 0.7640449438202247, 0.7740112994350282, 0.7796610169491526, 0.807909604519774]
# Average accuracy of Gaussian is:       76.78%

# %%
avg_g_precision = sum(g_precision)/k
print("Precision of Gaussian of each fold is:\n{}".format(g_precision))
print("precision accuracy of Gaussian is:    {:.2f}% \n".format(100*avg_g_precision))

avg_g_recall = sum(g_recall)/k
print("Recall of Gaussian of each fold is:\n{}".format(g_recall))
print("Recall accuracy of Gaussian is:       {:.2f}% \n".format(100*avg_g_recall))

avg_g_f1 = sum(g_f1)/k
print("F1 of Gaussian of each fold is:\n{} ".format(g_f1))
print("F1 accuracy of Gaussian is:           {:.2f}% \n".format(100*avg_g_f1))
# Out:
# Precision of Gaussian of each fold is:
# [0.5487804878048781, 0.7176470588235294, 0.6666666666666666, 0.7424242424242424, 0.7230769230769231]
# precision accuracy of Gaussian is:    67.97%
#
# Recall of Gaussian of each fold is:
# [0.7627118644067796, 0.7721518987341772, 0.8571428571428571, 0.6901408450704225, 0.746031746031746]
# Recall accuracy of Gaussian is:       76.56%
#
# F1 of Gaussian of each fold is:
# [0.6382978723404256, 0.7439024390243902, 0.75, 0.7153284671532847, 0.7343749999999999]
# F1 accuracy of Gaussian is:           71.64%

# %% [markdown]
# ### Q2. determine the number attributes that is capable of giving the best prediction of ‘daily returns’.

# %% [markdown]
# #### loading data

# %%
df = pd.read_csv('./IBM.txt', delimiter = " ")
df_raw = df
print("Number of rows in original data: {}".format(len(df.index)))
print("Features: ", list(df.columns))
# Out:
# Number of rows in original data: 3692
# Features:  ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adjusted']

# %%
pd.options.mode.chained_assignment = None

df['Daily_returns'] = 100*((df['Close'] - df['Close'].shift())/ df['Close'].shift())
conditions = [(df['Daily_returns'] >= 0.0),(df['Daily_returns'] < 0.0)]
# 1 for UP. -1 for Down

values1 = [1, -1]
df['Decision'] = np.select(conditions, values1)
df['Decision(next_day)'] = df['Decision'].shift(-1)
print("Number of rows in processed data: {}".format(len(df.index)))

df_new = df[1:-2]
df_new['Decision(next_day)'] = df_new['Decision(next_day)'].astype('int32')
df_new.head(8)
# Out:
# Number of rows in processed data: 3692
#          Date       Open        High        Low       Close    Volume  \
# 1  2007-01-04  97.250000   98.790001  96.879997   98.309998  10524500
# 2  2007-01-05  97.599998   97.949997  96.910004   97.419998   7221300
# 3  2007-01-08  98.500000   99.500000  98.349998   98.900002  10340000
# 4  2007-01-09  99.080002  100.330002  99.070000  100.070000  11108200
# 5  2007-01-10  98.500000   99.050003  97.930000   98.889999   8744800
# 6  2007-01-11  99.000000   99.900002  98.500000   98.650002   8000700
# 7  2007-01-12  98.989998   99.690002  98.500000   99.339996   6636500
# 8  2007-01-16  99.400002  100.839996  99.300003  100.820000   9602200
#
#     Adjusted  Daily_returns  Decision  Decision(next_day)
# 1  63.802544       1.069190         1                  -1
# 2  63.224930      -0.905300        -1                   1
# 3  64.185463       1.519199         1                   1
# 4  64.944771       1.183011         1                  -1
# 5  64.178978      -1.179176        -1                  -1
# 6  64.023201      -0.242691        -1                   1
# 7  64.471024       0.699436         1                   1
# 8  65.431503       1.489837         1                  -1

# %%
pd.options.mode.chained_assignment = None

df_new.loc[df_new['Open'] < 100, 'Open'] = 100
df_new.loc[(df_new['Open'] > 100)&(df_new['Open'] < 120), 'Open'] = 120
df_new.loc[df_new['Open'] > 120, 'Open'] = 150

df_new.loc[df_new['High'] < 100, 'High'] = 100
df_new.loc[((df_new['High'] > 100)&(df_new['High'] < 120)), 'High'] = 120
df_new.loc[df_new['High'] > 120, 'High'] = 150

df_new.loc[df_new['Low'] < 100, 'Low'] = 100
df_new.loc[((df_new['Low'] > 100)&(df_new['Low'] < 120)), 'Low'] = 120
df_new.loc[df_new['Low'] > 120, 'Low'] = 150

df_new.loc[df_new['Adjusted'] < 100, 'Adjusted'] = 100
df_new.loc[((df_new['Adjusted'] > 100)&(df_new['Adjusted'] < 120)), 'Adjusted'] = 120
df_new.loc[df_new['Adjusted'] > 120, 'Adjusted'] = 150

df_new.loc[df_new['Close'] < 100, 'Close'] = 100
df_new.loc[((df_new['Close'] > 100)&(df_new['Close'] < 120)), 'Close'] = 120
df_new.loc[df_new['Close'] > 120, 'Close'] = 150

df_new.loc[df_new['Volume'] <= 3039600, 'Volume'] = 100
df_new.loc[((df_new['Volume'] > 3039600)&(df_new['Volume'] < 10000000)), 'Volume'] = 120
df_new.loc[df_new['Volume'] > 10000000, 'Volume'] = 150
df_new
# Out:
#             Date   Open   High    Low  Close  Volume  Adjusted  Daily_returns  \
# 1     2007-01-04  100.0  100.0  100.0  100.0     150     100.0       1.069190
# 2     2007-01-05  100.0  100.0  100.0  100.0     120     100.0      -0.905300
# 3     2007-01-08  100.0  100.0  100.0  100.0     150     100.0       1.519199
# 4     2007-01-09  100.0  120.0  100.0  120.0     150     100.0       1.183011
# 5     2007-01-10  100.0  100.0  100.0  100.0     120     100.0      -1.179176
# ...          ...    ...    ...    ...    ...     ...       ...            ...
# 3685  2021-08-23  150.0  150.0  150.0  150.0     100     150.0       0.366612
# 3686  2021-08-24  150.0  150.0  150.0  150.0     100     150.0       0.157571
# 3687  2021-08-25  150.0  150.0  150.0  150.0     100     150.0       0.014306
# 3688  2021-08-26  150.0  150.0  150.0  150.0     100     150.0      -0.772202
# 3689  2021-08-27  150.0  150.0  150.0  150.0     100     150.0       0.453960
#
#       Decision  Decision(next_day)
# 1            1                  -1
# 2           -1                   1
# 3            1                   1
# 4            1                  -1
# 5           -1                  -1
# ...        ...                 ...
# 3685         1                   1
# 3686         1                   1
# 3687         1                  -1
# 3688        -1                   1
# 3689         1                  -1
#
# [3689 rows x 10 columns]

# %% [markdown]
# #### Split the data. Last 100 rows as test

# %%
df_new_IBM = df_new.copy()
xd_IBM = df_new_IBM[[ "Open", "High", "Low", "Close","Volume", "Adjusted"]]
le = preprocessing.LabelEncoder()
decision = le.fit(df_new_IBM["Decision(next_day)"])
decision = le.transform(df_new_IBM["Decision(next_day)"])

xd_train_dt =  xd_IBM[:-102]
xd_test_dt  =  xd_IBM[-102:-2]

yd_train_dt =  decision[:-102]
yd_test_dt  =  decision[-102:-2]

print("No of training samples : {}".format(xd_train_dt.shape))
print("No of test samples     : {}\n".format(xd_test_dt.shape))
print("y training samples     : {}".format(yd_train_dt.shape))
print("y test samples         : {}\n".format(yd_test_dt.shape))
# Out:
# No of training samples : (3587, 6)
# No of test samples     : (100, 6)
#
# y training samples     : (3587,)
# y test samples         : (100,)

# %%
feat_names = np.array(["Open", "High", "Low", "Close","Volume", "Adjusted"])
from itertools import chain, combinations
s = [x for x in range(6)]
all_combinations = chain.from_iterable(combinations(s, r) for r in range(len(s)+1))
all_combinations = list(all_combinations)[1:]

best_acc = 0.0

for depth in range(2,9):
    for attributes in all_combinations:
            dt_classifier_IBM = DecisionTreeClassifier(criterion = "entropy", max_depth = depth)

            attributes = list(attributes)

            xd_train_dt_IBM = xd_train_dt.iloc[:, attributes]
            xd_test_dt_IBM = xd_test_dt.iloc[:,attributes]

            dt_classifier_IBM.fit(xd_train_dt_IBM.values, yd_train_dt)
            y_pred_dt = dt_classifier_IBM.predict(xd_test_dt_IBM.values)
            acc_dt = accuracy_score(yd_test_dt, y_pred_dt)
            print("Depth {} of tree selecting {}/6 attributes: {:40s} Accuracy: {:.2f}%"
                  .format(depth, len(attributes), ",".join(feat_names[attributes]), 100*acc_dt))

            #print("confusion_matrix: \n",confusion_matrix(yd_test_knn,y_pred_knn))

            if best_acc < acc_dt:
                best_attributes = feat_names[attributes]
                best_acc = acc_dt
                best_depth = depth
# Out:
# Depth 2 of tree selecting 1/6 attributes: Open                                     Accuracy: 56.00%
# Depth 2 of tree selecting 1/6 attributes: High                                     Accuracy: 56.00%
# Depth 2 of tree selecting 1/6 attributes: Low                                      Accuracy: 56.00%
# Depth 2 of tree selecting 1/6 attributes: Close                                    Accuracy: 56.00%
# Depth 2 of tree selecting 1/6 attributes: Volume                                   Accuracy: 56.00%
# Depth 2 of tree selecting 1/6 attributes: Adjusted                                 Accuracy: 44.00%
# Depth 2 of tree selecting 2/6 attributes: Open,High                                Accuracy: 56.00%
# Depth 2 of tree selecting 2/6 attributes: Open,Low                                 Accuracy: 56.00%
# Depth 2 of tree selecting 2/6 attributes: Open,Close                               Accuracy: 56.00%
# Depth 2 of tree selecting 2/6 attributes: Open,Volume                              Accuracy: 56.00%
# Depth 2 of tree selecting 2/6 attributes: Open,Adjusted                            Accuracy: 44.00%
# Depth 2 of tree selecting 2/6 attributes: High,Low                                 Accuracy: 56.00%
# Depth 2 of tree selecting 2/6 attributes: High,Close                               Accuracy: 56.00%
# Depth 2 of tree selecting 2/6 attributes: High,Volume                              Accuracy: 56.00%
# Depth 2 of tree selecting 2/6 attributes: High,Adjusted                            Accuracy: 44.00%
# Depth 2 of tree selecting 2/6 attributes: Low,Close                                Accuracy: 56.00%
# Depth 2 of tree selecting 2/6 attributes: Low,Volume                               Accuracy: 56.00%
# Depth 2 of tree selecting 2/6 attributes: Low,Adjusted                             Accuracy: 44.00%
# Depth 2 of tree selecting 2/6 attributes: Close,Volume                             Accuracy: 56.00%
# Depth 2 of tree selecting 2/6 attributes: Close,Adjusted                           Accuracy: 44.00%
# Depth 2 of tree selecting 2/6 attributes: Volume,Adjusted                          Accuracy: 50.00%
# Depth 2 of tree selecting 3/6 attributes: Open,High,Low                            Accuracy: 56.00%
# Depth 2 of tree selecting 3/6 attributes: Open,High,Close                          Accuracy: 56.00%
# Depth 2 of tree selecting 3/6 attributes: Open,High,Volume                         Accuracy: 56.00%
# Depth 2 of tree selecting 3/6 attributes: Open,High,Adjusted                       Accuracy: 44.00%
# Depth 2 of tree selecting 3/6 attributes: Open,Low,Close                           Accuracy: 56.00%
# Depth 2 of tree selecting 3/6 attributes: Open,Low,Volume                          Accuracy: 56.00%
# Depth 2 of tree selecting 3/6 attributes: Open,Low,Adjusted                        Accuracy: 44.00%
# Depth 2 of tree selecting 3/6 attributes: Open,Close,Volume                        Accuracy: 56.00%
# Depth 2 of tree selecting 3/6 attributes: Open,Close,Adjusted                      Accuracy: 44.00%
# Depth 2 of tree selecting 3/6 attributes: Open,Volume,Adjusted                     Accuracy: 50.00%
# Depth 2 of tree selecting 3/6 attributes: High,Low,Close                           Accuracy: 56.00%
# Depth 2 of tree selecting 3/6 attributes: High,Low,Volume                          Accuracy: 56.00%
# Depth 2 of tree selecting 3/6 attributes: High,Low,Adjusted                        Accuracy: 44.00%
# Depth 2 of tree selecting 3/6 attributes: High,Close,Volume                        Accuracy: 56.00%
# Depth 2 of tree selecting 3/6 attributes: High,Close,Adjusted                      Accuracy: 44.00%
# Depth 2 of tree selecting 3/6 attributes: High,Volume,Adjusted                     Accuracy: 50.00%
# Depth 2 of tree selecting 3/6 attributes: Low,Close,Volume                         Accuracy: 56.00%
# Depth 2 of tree selecting 3/6 attributes: Low,Close,Adjusted                       Accuracy: 44.00%
# Depth 2 of tree selecting 3/6 attributes: Low,Volume,Adjusted                      Accuracy: 50.00%
# Depth 2 of tree selecting 3/6 attributes: Close,Volume,Adjusted                    Accuracy: 50.00%
# Depth 2 of tree selecting 4/6 attributes: Open,High,Low,Close                      Accuracy: 56.00%
# Depth 2 of tree selecting 4/6 attributes: Open,High,Low,Volume                     Accuracy: 56.00%
# Depth 2 of tree selecting 4/6 attributes: Open,High,Low,Adjusted                   Accuracy: 44.00%
# Depth 2 of tree selecting 4/6 attributes: Open,High,Close,Volume                   Accuracy: 56.00%
# Depth 2 of tree selecting 4/6 attributes: Open,High,Close,Adjusted                 Accuracy: 44.00%
# Depth 2 of tree selecting 4/6 attributes: Open,High,Volume,Adjusted                Accuracy: 50.00%
# Depth 2 of tree selecting 4/6 attributes: Open,Low,Close,Volume                    Accuracy: 56.00%
# Depth 2 of tree selecting 4/6 attributes: Open,Low,Close,Adjusted                  Accuracy: 44.00%
# Depth 2 of tree selecting 4/6 attributes: Open,Low,Volume,Adjusted                 Accuracy: 50.00%
# Depth 2 of tree selecting 4/6 attributes: Open,Close,Volume,Adjusted               Accuracy: 50.00%
# Depth 2 of tree selecting 4/6 attributes: High,Low,Close,Volume                    Accuracy: 56.00%
# Depth 2 of tree selecting 4/6 attributes: High,Low,Close,Adjusted                  Accuracy: 44.00%
# Depth 2 of tree selecting 4/6 attributes: High,Low,Volume,Adjusted                 Accuracy: 50.00%
# Depth 2 of tree selecting 4/6 attributes: High,Close,Volume,Adjusted               Accuracy: 50.00%
# Depth 2 of tree selecting 4/6 attributes: Low,Close,Volume,Adjusted                Accuracy: 50.00%
# Depth 2 of tree selecting 5/6 attributes: Open,High,Low,Close,Volume               Accuracy: 56.00%
# Depth 2 of tree selecting 5/6 attributes: Open,High,Low,Close,Adjusted             Accuracy: 44.00%
# Depth 2 of tree selecting 5/6 attributes: Open,High,Low,Volume,Adjusted            Accuracy: 50.00%
# Depth 2 of tree selecting 5/6 attributes: Open,High,Close,Volume,Adjusted          Accuracy: 50.00%
# Depth 2 of tree selecting 5/6 attributes: Open,Low,Close,Volume,Adjusted           Accuracy: 50.00%
# Depth 2 of tree selecting 5/6 attributes: High,Low,Close,Volume,Adjusted           Accuracy: 50.00%
# Depth 2 of tree selecting 6/6 attributes: Open,High,Low,Close,Volume,Adjusted      Accuracy: 50.00%
# Depth 3 of tree selecting 1/6 attributes: Open                                     Accuracy: 56.00%
# Depth 3 of tree selecting 1/6 attributes: High                                     Accuracy: 56.00%
# Depth 3 of tree selecting 1/6 attributes: Low                                      Accuracy: 56.00%
# Depth 3 of tree selecting 1/6 attributes: Close                                    Accuracy: 56.00%
# Depth 3 of tree selecting 1/6 attributes: Volume                                   Accuracy: 56.00%
# Depth 3 of tree selecting 1/6 attributes: Adjusted                                 Accuracy: 44.00%
# Depth 3 of tree selecting 2/6 attributes: Open,High                                Accuracy: 56.00%
# Depth 3 of tree selecting 2/6 attributes: Open,Low                                 Accuracy: 56.00%
# Depth 3 of tree selecting 2/6 attributes: Open,Close                               Accuracy: 56.00%
# Depth 3 of tree selecting 2/6 attributes: Open,Volume                              Accuracy: 56.00%
# Depth 3 of tree selecting 2/6 attributes: Open,Adjusted                            Accuracy: 44.00%
# Depth 3 of tree selecting 2/6 attributes: High,Low                                 Accuracy: 56.00%
# Depth 3 of tree selecting 2/6 attributes: High,Close                               Accuracy: 56.00%
# Depth 3 of tree selecting 2/6 attributes: High,Volume                              Accuracy: 56.00%
# Depth 3 of tree selecting 2/6 attributes: High,Adjusted                            Accuracy: 44.00%
# Depth 3 of tree selecting 2/6 attributes: Low,Close                                Accuracy: 56.00%
# Depth 3 of tree selecting 2/6 attributes: Low,Volume                               Accuracy: 56.00%
# Depth 3 of tree selecting 2/6 attributes: Low,Adjusted                             Accuracy: 44.00%
# Depth 3 of tree selecting 2/6 attributes: Close,Volume                             Accuracy: 56.00%
# Depth 3 of tree selecting 2/6 attributes: Close,Adjusted                           Accuracy: 44.00%
# Depth 3 of tree selecting 2/6 attributes: Volume,Adjusted                          Accuracy: 50.00%
# Depth 3 of tree selecting 3/6 attributes: Open,High,Low                            Accuracy: 56.00%
# Depth 3 of tree selecting 3/6 attributes: Open,High,Close                          Accuracy: 56.00%
# Depth 3 of tree selecting 3/6 attributes: Open,High,Volume                         Accuracy: 56.00%
# Depth 3 of tree selecting 3/6 attributes: Open,High,Adjusted                       Accuracy: 44.00%
# Depth 3 of tree selecting 3/6 attributes: Open,Low,Close                           Accuracy: 56.00%
# Depth 3 of tree selecting 3/6 attributes: Open,Low,Volume                          Accuracy: 56.00%
# Depth 3 of tree selecting 3/6 attributes: Open,Low,Adjusted                        Accuracy: 44.00%
# Depth 3 of tree selecting 3/6 attributes: Open,Close,Volume                        Accuracy: 56.00%
# Depth 3 of tree selecting 3/6 attributes: Open,Close,Adjusted                      Accuracy: 44.00%
# Depth 3 of tree selecting 3/6 attributes: Open,Volume,Adjusted                     Accuracy: 50.00%
# Depth 3 of tree selecting 3/6 attributes: High,Low,Close                           Accuracy: 56.00%
# Depth 3 of tree selecting 3/6 attributes: High,Low,Volume                          Accuracy: 56.00%
# Depth 3 of tree selecting 3/6 attributes: High,Low,Adjusted                        Accuracy: 44.00%
# Depth 3 of tree selecting 3/6 attributes: High,Close,Volume                        Accuracy: 56.00%
# Depth 3 of tree selecting 3/6 attributes: High,Close,Adjusted                      Accuracy: 44.00%
# Depth 3 of tree selecting 3/6 attributes: High,Volume,Adjusted                     Accuracy: 50.00%
# Depth 3 of tree selecting 3/6 attributes: Low,Close,Volume                         Accuracy: 56.00%
# Depth 3 of tree selecting 3/6 attributes: Low,Close,Adjusted                       Accuracy: 44.00%
# Depth 3 of tree selecting 3/6 attributes: Low,Volume,Adjusted                      Accuracy: 50.00%
# Depth 3 of tree selecting 3/6 attributes: Close,Volume,Adjusted                    Accuracy: 50.00%
# Depth 3 of tree selecting 4/6 attributes: Open,High,Low,Close                      Accuracy: 56.00%
# Depth 3 of tree selecting 4/6 attributes: Open,High,Low,Volume                     Accuracy: 56.00%
# Depth 3 of tree selecting 4/6 attributes: Open,High,Low,Adjusted                   Accuracy: 44.00%
# Depth 3 of tree selecting 4/6 attributes: Open,High,Close,Volume                   Accuracy: 56.00%
# Depth 3 of tree selecting 4/6 attributes: Open,High,Close,Adjusted                 Accuracy: 44.00%
# Depth 3 of tree selecting 4/6 attributes: Open,High,Volume,Adjusted                Accuracy: 50.00%
# Depth 3 of tree selecting 4/6 attributes: Open,Low,Close,Volume                    Accuracy: 56.00%
# Depth 3 of tree selecting 4/6 attributes: Open,Low,Close,Adjusted                  Accuracy: 44.00%
# Depth 3 of tree selecting 4/6 attributes: Open,Low,Volume,Adjusted                 Accuracy: 50.00%
# Depth 3 of tree selecting 4/6 attributes: Open,Close,Volume,Adjusted               Accuracy: 50.00%
# Depth 3 of tree selecting 4/6 attributes: High,Low,Close,Volume                    Accuracy: 56.00%
# Depth 3 of tree selecting 4/6 attributes: High,Low,Close,Adjusted                  Accuracy: 44.00%
# Depth 3 of tree selecting 4/6 attributes: High,Low,Volume,Adjusted                 Accuracy: 50.00%
# Depth 3 of tree selecting 4/6 attributes: High,Close,Volume,Adjusted               Accuracy: 50.00%
# Depth 3 of tree selecting 4/6 attributes: Low,Close,Volume,Adjusted                Accuracy: 50.00%
# Depth 3 of tree selecting 5/6 attributes: Open,High,Low,Close,Volume               Accuracy: 56.00%
# Depth 3 of tree selecting 5/6 attributes: Open,High,Low,Close,Adjusted             Accuracy: 44.00%
# Depth 3 of tree selecting 5/6 attributes: Open,High,Low,Volume,Adjusted            Accuracy: 50.00%
# Depth 3 of tree selecting 5/6 attributes: Open,High,Close,Volume,Adjusted          Accuracy: 50.00%
# Depth 3 of tree selecting 5/6 attributes: Open,Low,Close,Volume,Adjusted           Accuracy: 50.00%
# Depth 3 of tree selecting 5/6 attributes: High,Low,Close,Volume,Adjusted           Accuracy: 50.00%
# Depth 3 of tree selecting 6/6 attributes: Open,High,Low,Close,Volume,Adjusted      Accuracy: 50.00%
# Depth 4 of tree selecting 1/6 attributes: Open                                     Accuracy: 56.00%
# Depth 4 of tree selecting 1/6 attributes: High                                     Accuracy: 56.00%
# Depth 4 of tree selecting 1/6 attributes: Low                                      Accuracy: 56.00%
# Depth 4 of tree selecting 1/6 attributes: Close                                    Accuracy: 56.00%
# Depth 4 of tree selecting 1/6 attributes: Volume                                   Accuracy: 56.00%
# Depth 4 of tree selecting 1/6 attributes: Adjusted                                 Accuracy: 44.00%
# Depth 4 of tree selecting 2/6 attributes: Open,High                                Accuracy: 56.00%
# Depth 4 of tree selecting 2/6 attributes: Open,Low                                 Accuracy: 56.00%
# Depth 4 of tree selecting 2/6 attributes: Open,Close                               Accuracy: 56.00%
# Depth 4 of tree selecting 2/6 attributes: Open,Volume                              Accuracy: 56.00%
# Depth 4 of tree selecting 2/6 attributes: Open,Adjusted                            Accuracy: 44.00%
# Depth 4 of tree selecting 2/6 attributes: High,Low                                 Accuracy: 56.00%
# Depth 4 of tree selecting 2/6 attributes: High,Close                               Accuracy: 56.00%
# Depth 4 of tree selecting 2/6 attributes: High,Volume                              Accuracy: 56.00%
# Depth 4 of tree selecting 2/6 attributes: High,Adjusted                            Accuracy: 44.00%
# Depth 4 of tree selecting 2/6 attributes: Low,Close                                Accuracy: 56.00%
# Depth 4 of tree selecting 2/6 attributes: Low,Volume                               Accuracy: 56.00%
# Depth 4 of tree selecting 2/6 attributes: Low,Adjusted                             Accuracy: 44.00%
# Depth 4 of tree selecting 2/6 attributes: Close,Volume                             Accuracy: 56.00%
# Depth 4 of tree selecting 2/6 attributes: Close,Adjusted                           Accuracy: 44.00%
# Depth 4 of tree selecting 2/6 attributes: Volume,Adjusted                          Accuracy: 50.00%
# Depth 4 of tree selecting 3/6 attributes: Open,High,Low                            Accuracy: 56.00%
# Depth 4 of tree selecting 3/6 attributes: Open,High,Close                          Accuracy: 56.00%
# Depth 4 of tree selecting 3/6 attributes: Open,High,Volume                         Accuracy: 56.00%
# Depth 4 of tree selecting 3/6 attributes: Open,High,Adjusted                       Accuracy: 44.00%
# Depth 4 of tree selecting 3/6 attributes: Open,Low,Close                           Accuracy: 56.00%
# Depth 4 of tree selecting 3/6 attributes: Open,Low,Volume                          Accuracy: 56.00%
# Depth 4 of tree selecting 3/6 attributes: Open,Low,Adjusted                        Accuracy: 44.00%
# Depth 4 of tree selecting 3/6 attributes: Open,Close,Volume                        Accuracy: 56.00%
# Depth 4 of tree selecting 3/6 attributes: Open,Close,Adjusted                      Accuracy: 44.00%
# Depth 4 of tree selecting 3/6 attributes: Open,Volume,Adjusted                     Accuracy: 50.00%
# Depth 4 of tree selecting 3/6 attributes: High,Low,Close                           Accuracy: 56.00%
# Depth 4 of tree selecting 3/6 attributes: High,Low,Volume                          Accuracy: 56.00%
# Depth 4 of tree selecting 3/6 attributes: High,Low,Adjusted                        Accuracy: 44.00%
# Depth 4 of tree selecting 3/6 attributes: High,Close,Volume                        Accuracy: 56.00%
# Depth 4 of tree selecting 3/6 attributes: High,Close,Adjusted                      Accuracy: 44.00%
# Depth 4 of tree selecting 3/6 attributes: High,Volume,Adjusted                     Accuracy: 50.00%
# Depth 4 of tree selecting 3/6 attributes: Low,Close,Volume                         Accuracy: 56.00%
# Depth 4 of tree selecting 3/6 attributes: Low,Close,Adjusted                       Accuracy: 44.00%
# Depth 4 of tree selecting 3/6 attributes: Low,Volume,Adjusted                      Accuracy: 50.00%
# Depth 4 of tree selecting 3/6 attributes: Close,Volume,Adjusted                    Accuracy: 50.00%
# Depth 4 of tree selecting 4/6 attributes: Open,High,Low,Close                      Accuracy: 56.00%
# Depth 4 of tree selecting 4/6 attributes: Open,High,Low,Volume                     Accuracy: 56.00%
# Depth 4 of tree selecting 4/6 attributes: Open,High,Low,Adjusted                   Accuracy: 44.00%
# Depth 4 of tree selecting 4/6 attributes: Open,High,Close,Volume                   Accuracy: 56.00%
# Depth 4 of tree selecting 4/6 attributes: Open,High,Close,Adjusted                 Accuracy: 44.00%
# Depth 4 of tree selecting 4/6 attributes: Open,High,Volume,Adjusted                Accuracy: 50.00%
# Depth 4 of tree selecting 4/6 attributes: Open,Low,Close,Volume                    Accuracy: 56.00%
# Depth 4 of tree selecting 4/6 attributes: Open,Low,Close,Adjusted                  Accuracy: 44.00%
# Depth 4 of tree selecting 4/6 attributes: Open,Low,Volume,Adjusted                 Accuracy: 50.00%
# Depth 4 of tree selecting 4/6 attributes: Open,Close,Volume,Adjusted               Accuracy: 50.00%
# Depth 4 of tree selecting 4/6 attributes: High,Low,Close,Volume                    Accuracy: 56.00%
# Depth 4 of tree selecting 4/6 attributes: High,Low,Close,Adjusted                  Accuracy: 44.00%
# Depth 4 of tree selecting 4/6 attributes: High,Low,Volume,Adjusted                 Accuracy: 50.00%
# Depth 4 of tree selecting 4/6 attributes: High,Close,Volume,Adjusted               Accuracy: 50.00%
# Depth 4 of tree selecting 4/6 attributes: Low,Close,Volume,Adjusted                Accuracy: 50.00%
# Depth 4 of tree selecting 5/6 attributes: Open,High,Low,Close,Volume               Accuracy: 56.00%
# Depth 4 of tree selecting 5/6 attributes: Open,High,Low,Close,Adjusted             Accuracy: 44.00%
# Depth 4 of tree selecting 5/6 attributes: Open,High,Low,Volume,Adjusted            Accuracy: 50.00%
# Depth 4 of tree selecting 5/6 attributes: Open,High,Close,Volume,Adjusted          Accuracy: 50.00%
# Depth 4 of tree selecting 5/6 attributes: Open,Low,Close,Volume,Adjusted           Accuracy: 50.00%
# Depth 4 of tree selecting 5/6 attributes: High,Low,Close,Volume,Adjusted           Accuracy: 50.00%
# Depth 4 of tree selecting 6/6 attributes: Open,High,Low,Close,Volume,Adjusted      Accuracy: 50.00%
# Depth 5 of tree selecting 1/6 attributes: Open                                     Accuracy: 56.00%
# Depth 5 of tree selecting 1/6 attributes: High                                     Accuracy: 56.00%
# Depth 5 of tree selecting 1/6 attributes: Low                                      Accuracy: 56.00%
# Depth 5 of tree selecting 1/6 attributes: Close                                    Accuracy: 56.00%
# Depth 5 of tree selecting 1/6 attributes: Volume                                   Accuracy: 56.00%
# Depth 5 of tree selecting 1/6 attributes: Adjusted                                 Accuracy: 44.00%
# Depth 5 of tree selecting 2/6 attributes: Open,High                                Accuracy: 56.00%
# Depth 5 of tree selecting 2/6 attributes: Open,Low                                 Accuracy: 56.00%
# Depth 5 of tree selecting 2/6 attributes: Open,Close                               Accuracy: 56.00%
# Depth 5 of tree selecting 2/6 attributes: Open,Volume                              Accuracy: 56.00%
# Depth 5 of tree selecting 2/6 attributes: Open,Adjusted                            Accuracy: 44.00%
# Depth 5 of tree selecting 2/6 attributes: High,Low                                 Accuracy: 56.00%
# Depth 5 of tree selecting 2/6 attributes: High,Close                               Accuracy: 56.00%
# Depth 5 of tree selecting 2/6 attributes: High,Volume                              Accuracy: 56.00%
# Depth 5 of tree selecting 2/6 attributes: High,Adjusted                            Accuracy: 44.00%
# Depth 5 of tree selecting 2/6 attributes: Low,Close                                Accuracy: 56.00%
# Depth 5 of tree selecting 2/6 attributes: Low,Volume                               Accuracy: 56.00%
# Depth 5 of tree selecting 2/6 attributes: Low,Adjusted                             Accuracy: 44.00%
# Depth 5 of tree selecting 2/6 attributes: Close,Volume                             Accuracy: 56.00%
# Depth 5 of tree selecting 2/6 attributes: Close,Adjusted                           Accuracy: 44.00%
# Depth 5 of tree selecting 2/6 attributes: Volume,Adjusted                          Accuracy: 50.00%
# Depth 5 of tree selecting 3/6 attributes: Open,High,Low                            Accuracy: 56.00%
# Depth 5 of tree selecting 3/6 attributes: Open,High,Close                          Accuracy: 56.00%
# Depth 5 of tree selecting 3/6 attributes: Open,High,Volume                         Accuracy: 56.00%
# Depth 5 of tree selecting 3/6 attributes: Open,High,Adjusted                       Accuracy: 44.00%
# Depth 5 of tree selecting 3/6 attributes: Open,Low,Close                           Accuracy: 56.00%
# Depth 5 of tree selecting 3/6 attributes: Open,Low,Volume                          Accuracy: 56.00%
# Depth 5 of tree selecting 3/6 attributes: Open,Low,Adjusted                        Accuracy: 44.00%
# Depth 5 of tree selecting 3/6 attributes: Open,Close,Volume                        Accuracy: 56.00%
# Depth 5 of tree selecting 3/6 attributes: Open,Close,Adjusted                      Accuracy: 44.00%
# Depth 5 of tree selecting 3/6 attributes: Open,Volume,Adjusted                     Accuracy: 50.00%
# Depth 5 of tree selecting 3/6 attributes: High,Low,Close                           Accuracy: 56.00%
# Depth 5 of tree selecting 3/6 attributes: High,Low,Volume                          Accuracy: 56.00%
# Depth 5 of tree selecting 3/6 attributes: High,Low,Adjusted                        Accuracy: 44.00%
# Depth 5 of tree selecting 3/6 attributes: High,Close,Volume                        Accuracy: 56.00%
# Depth 5 of tree selecting 3/6 attributes: High,Close,Adjusted                      Accuracy: 44.00%
# Depth 5 of tree selecting 3/6 attributes: High,Volume,Adjusted                     Accuracy: 50.00%
# Depth 5 of tree selecting 3/6 attributes: Low,Close,Volume                         Accuracy: 56.00%
# Depth 5 of tree selecting 3/6 attributes: Low,Close,Adjusted                       Accuracy: 44.00%
# Depth 5 of tree selecting 3/6 attributes: Low,Volume,Adjusted                      Accuracy: 50.00%
# Depth 5 of tree selecting 3/6 attributes: Close,Volume,Adjusted                    Accuracy: 50.00%
# Depth 5 of tree selecting 4/6 attributes: Open,High,Low,Close                      Accuracy: 56.00%
# Depth 5 of tree selecting 4/6 attributes: Open,High,Low,Volume                     Accuracy: 56.00%
# Depth 5 of tree selecting 4/6 attributes: Open,High,Low,Adjusted                   Accuracy: 44.00%
# Depth 5 of tree selecting 4/6 attributes: Open,High,Close,Volume                   Accuracy: 56.00%
# Depth 5 of tree selecting 4/6 attributes: Open,High,Close,Adjusted                 Accuracy: 44.00%
# Depth 5 of tree selecting 4/6 attributes: Open,High,Volume,Adjusted                Accuracy: 50.00%
# Depth 5 of tree selecting 4/6 attributes: Open,Low,Close,Volume                    Accuracy: 56.00%
# Depth 5 of tree selecting 4/6 attributes: Open,Low,Close,Adjusted                  Accuracy: 44.00%
# Depth 5 of tree selecting 4/6 attributes: Open,Low,Volume,Adjusted                 Accuracy: 50.00%
# Depth 5 of tree selecting 4/6 attributes: Open,Close,Volume,Adjusted               Accuracy: 50.00%
# Depth 5 of tree selecting 4/6 attributes: High,Low,Close,Volume                    Accuracy: 56.00%
# Depth 5 of tree selecting 4/6 attributes: High,Low,Close,Adjusted                  Accuracy: 44.00%
# Depth 5 of tree selecting 4/6 attributes: High,Low,Volume,Adjusted                 Accuracy: 50.00%
# Depth 5 of tree selecting 4/6 attributes: High,Close,Volume,Adjusted               Accuracy: 50.00%
# Depth 5 of tree selecting 4/6 attributes: Low,Close,Volume,Adjusted                Accuracy: 50.00%
# Depth 5 of tree selecting 5/6 attributes: Open,High,Low,Close,Volume               Accuracy: 56.00%
# Depth 5 of tree selecting 5/6 attributes: Open,High,Low,Close,Adjusted             Accuracy: 44.00%
# Depth 5 of tree selecting 5/6 attributes: Open,High,Low,Volume,Adjusted            Accuracy: 50.00%
# Depth 5 of tree selecting 5/6 attributes: Open,High,Close,Volume,Adjusted          Accuracy: 50.00%
# Depth 5 of tree selecting 5/6 attributes: Open,Low,Close,Volume,Adjusted           Accuracy: 50.00%
# Depth 5 of tree selecting 5/6 attributes: High,Low,Close,Volume,Adjusted           Accuracy: 50.00%
# Depth 5 of tree selecting 6/6 attributes: Open,High,Low,Close,Volume,Adjusted      Accuracy: 50.00%
# Depth 6 of tree selecting 1/6 attributes: Open                                     Accuracy: 56.00%
# Depth 6 of tree selecting 1/6 attributes: High                                     Accuracy: 56.00%
# Depth 6 of tree selecting 1/6 attributes: Low                                      Accuracy: 56.00%
# Depth 6 of tree selecting 1/6 attributes: Close                                    Accuracy: 56.00%
# Depth 6 of tree selecting 1/6 attributes: Volume                                   Accuracy: 56.00%
# Depth 6 of tree selecting 1/6 attributes: Adjusted                                 Accuracy: 44.00%
# Depth 6 of tree selecting 2/6 attributes: Open,High                                Accuracy: 56.00%
# Depth 6 of tree selecting 2/6 attributes: Open,Low                                 Accuracy: 56.00%
# Depth 6 of tree selecting 2/6 attributes: Open,Close                               Accuracy: 56.00%
# Depth 6 of tree selecting 2/6 attributes: Open,Volume                              Accuracy: 56.00%
# Depth 6 of tree selecting 2/6 attributes: Open,Adjusted                            Accuracy: 44.00%
# Depth 6 of tree selecting 2/6 attributes: High,Low                                 Accuracy: 56.00%
# Depth 6 of tree selecting 2/6 attributes: High,Close                               Accuracy: 56.00%
# Depth 6 of tree selecting 2/6 attributes: High,Volume                              Accuracy: 56.00%
# Depth 6 of tree selecting 2/6 attributes: High,Adjusted                            Accuracy: 44.00%
# Depth 6 of tree selecting 2/6 attributes: Low,Close                                Accuracy: 56.00%
# Depth 6 of tree selecting 2/6 attributes: Low,Volume                               Accuracy: 56.00%
# Depth 6 of tree selecting 2/6 attributes: Low,Adjusted                             Accuracy: 44.00%
# Depth 6 of tree selecting 2/6 attributes: Close,Volume                             Accuracy: 56.00%
# Depth 6 of tree selecting 2/6 attributes: Close,Adjusted                           Accuracy: 44.00%
# Depth 6 of tree selecting 2/6 attributes: Volume,Adjusted                          Accuracy: 50.00%
# Depth 6 of tree selecting 3/6 attributes: Open,High,Low                            Accuracy: 56.00%
# Depth 6 of tree selecting 3/6 attributes: Open,High,Close                          Accuracy: 56.00%
# Depth 6 of tree selecting 3/6 attributes: Open,High,Volume                         Accuracy: 56.00%
# Depth 6 of tree selecting 3/6 attributes: Open,High,Adjusted                       Accuracy: 44.00%
# Depth 6 of tree selecting 3/6 attributes: Open,Low,Close                           Accuracy: 56.00%
# Depth 6 of tree selecting 3/6 attributes: Open,Low,Volume                          Accuracy: 56.00%
# Depth 6 of tree selecting 3/6 attributes: Open,Low,Adjusted                        Accuracy: 44.00%
# Depth 6 of tree selecting 3/6 attributes: Open,Close,Volume                        Accuracy: 56.00%
# Depth 6 of tree selecting 3/6 attributes: Open,Close,Adjusted                      Accuracy: 44.00%
# Depth 6 of tree selecting 3/6 attributes: Open,Volume,Adjusted                     Accuracy: 50.00%
# Depth 6 of tree selecting 3/6 attributes: High,Low,Close                           Accuracy: 56.00%
# Depth 6 of tree selecting 3/6 attributes: High,Low,Volume                          Accuracy: 56.00%
# Depth 6 of tree selecting 3/6 attributes: High,Low,Adjusted                        Accuracy: 44.00%
# Depth 6 of tree selecting 3/6 attributes: High,Close,Volume                        Accuracy: 56.00%
# Depth 6 of tree selecting 3/6 attributes: High,Close,Adjusted                      Accuracy: 44.00%
# Depth 6 of tree selecting 3/6 attributes: High,Volume,Adjusted                     Accuracy: 50.00%
# Depth 6 of tree selecting 3/6 attributes: Low,Close,Volume                         Accuracy: 56.00%
# Depth 6 of tree selecting 3/6 attributes: Low,Close,Adjusted                       Accuracy: 44.00%
# Depth 6 of tree selecting 3/6 attributes: Low,Volume,Adjusted                      Accuracy: 50.00%
# Depth 6 of tree selecting 3/6 attributes: Close,Volume,Adjusted                    Accuracy: 50.00%
# Depth 6 of tree selecting 4/6 attributes: Open,High,Low,Close                      Accuracy: 56.00%
# Depth 6 of tree selecting 4/6 attributes: Open,High,Low,Volume                     Accuracy: 56.00%
# Depth 6 of tree selecting 4/6 attributes: Open,High,Low,Adjusted                   Accuracy: 44.00%
# Depth 6 of tree selecting 4/6 attributes: Open,High,Close,Volume                   Accuracy: 56.00%
# Depth 6 of tree selecting 4/6 attributes: Open,High,Close,Adjusted                 Accuracy: 44.00%
# Depth 6 of tree selecting 4/6 attributes: Open,High,Volume,Adjusted                Accuracy: 50.00%
# Depth 6 of tree selecting 4/6 attributes: Open,Low,Close,Volume                    Accuracy: 56.00%
# Depth 6 of tree selecting 4/6 attributes: Open,Low,Close,Adjusted                  Accuracy: 44.00%
# Depth 6 of tree selecting 4/6 attributes: Open,Low,Volume,Adjusted                 Accuracy: 50.00%
# Depth 6 of tree selecting 4/6 attributes: Open,Close,Volume,Adjusted               Accuracy: 50.00%
# Depth 6 of tree selecting 4/6 attributes: High,Low,Close,Volume                    Accuracy: 56.00%
# Depth 6 of tree selecting 4/6 attributes: High,Low,Close,Adjusted                  Accuracy: 44.00%
# Depth 6 of tree selecting 4/6 attributes: High,Low,Volume,Adjusted                 Accuracy: 50.00%
# Depth 6 of tree selecting 4/6 attributes: High,Close,Volume,Adjusted               Accuracy: 50.00%
# Depth 6 of tree selecting 4/6 attributes: Low,Close,Volume,Adjusted                Accuracy: 50.00%
# Depth 6 of tree selecting 5/6 attributes: Open,High,Low,Close,Volume               Accuracy: 56.00%
# Depth 6 of tree selecting 5/6 attributes: Open,High,Low,Close,Adjusted             Accuracy: 44.00%
# Depth 6 of tree selecting 5/6 attributes: Open,High,Low,Volume,Adjusted            Accuracy: 50.00%
# Depth 6 of tree selecting 5/6 attributes: Open,High,Close,Volume,Adjusted          Accuracy: 50.00%
# Depth 6 of tree selecting 5/6 attributes: Open,Low,Close,Volume,Adjusted           Accuracy: 50.00%
# Depth 6 of tree selecting 5/6 attributes: High,Low,Close,Volume,Adjusted           Accuracy: 50.00%
# Depth 6 of tree selecting 6/6 attributes: Open,High,Low,Close,Volume,Adjusted      Accuracy: 50.00%
# Depth 7 of tree selecting 1/6 attributes: Open                                     Accuracy: 56.00%
# Depth 7 of tree selecting 1/6 attributes: High                                     Accuracy: 56.00%
# Depth 7 of tree selecting 1/6 attributes: Low                                      Accuracy: 56.00%
# Depth 7 of tree selecting 1/6 attributes: Close                                    Accuracy: 56.00%
# Depth 7 of tree selecting 1/6 attributes: Volume                                   Accuracy: 56.00%
# Depth 7 of tree selecting 1/6 attributes: Adjusted                                 Accuracy: 44.00%
# Depth 7 of tree selecting 2/6 attributes: Open,High                                Accuracy: 56.00%
# Depth 7 of tree selecting 2/6 attributes: Open,Low                                 Accuracy: 56.00%
# Depth 7 of tree selecting 2/6 attributes: Open,Close                               Accuracy: 56.00%
# Depth 7 of tree selecting 2/6 attributes: Open,Volume                              Accuracy: 56.00%
# Depth 7 of tree selecting 2/6 attributes: Open,Adjusted                            Accuracy: 44.00%
# Depth 7 of tree selecting 2/6 attributes: High,Low                                 Accuracy: 56.00%
# Depth 7 of tree selecting 2/6 attributes: High,Close                               Accuracy: 56.00%
# Depth 7 of tree selecting 2/6 attributes: High,Volume                              Accuracy: 56.00%
# Depth 7 of tree selecting 2/6 attributes: High,Adjusted                            Accuracy: 44.00%
# Depth 7 of tree selecting 2/6 attributes: Low,Close                                Accuracy: 56.00%
# Depth 7 of tree selecting 2/6 attributes: Low,Volume                               Accuracy: 56.00%
# Depth 7 of tree selecting 2/6 attributes: Low,Adjusted                             Accuracy: 44.00%
# Depth 7 of tree selecting 2/6 attributes: Close,Volume                             Accuracy: 56.00%
# Depth 7 of tree selecting 2/6 attributes: Close,Adjusted                           Accuracy: 44.00%
# Depth 7 of tree selecting 2/6 attributes: Volume,Adjusted                          Accuracy: 50.00%
# Depth 7 of tree selecting 3/6 attributes: Open,High,Low                            Accuracy: 56.00%
# Depth 7 of tree selecting 3/6 attributes: Open,High,Close                          Accuracy: 56.00%
# Depth 7 of tree selecting 3/6 attributes: Open,High,Volume                         Accuracy: 56.00%
# Depth 7 of tree selecting 3/6 attributes: Open,High,Adjusted                       Accuracy: 44.00%
# Depth 7 of tree selecting 3/6 attributes: Open,Low,Close                           Accuracy: 56.00%
# Depth 7 of tree selecting 3/6 attributes: Open,Low,Volume                          Accuracy: 56.00%
# Depth 7 of tree selecting 3/6 attributes: Open,Low,Adjusted                        Accuracy: 44.00%
# Depth 7 of tree selecting 3/6 attributes: Open,Close,Volume                        Accuracy: 56.00%
# Depth 7 of tree selecting 3/6 attributes: Open,Close,Adjusted                      Accuracy: 44.00%
# Depth 7 of tree selecting 3/6 attributes: Open,Volume,Adjusted                     Accuracy: 50.00%
# Depth 7 of tree selecting 3/6 attributes: High,Low,Close                           Accuracy: 56.00%
# Depth 7 of tree selecting 3/6 attributes: High,Low,Volume                          Accuracy: 56.00%
# Depth 7 of tree selecting 3/6 attributes: High,Low,Adjusted                        Accuracy: 44.00%
# Depth 7 of tree selecting 3/6 attributes: High,Close,Volume                        Accuracy: 56.00%
# Depth 7 of tree selecting 3/6 attributes: High,Close,Adjusted                      Accuracy: 44.00%
# Depth 7 of tree selecting 3/6 attributes: High,Volume,Adjusted                     Accuracy: 50.00%
# Depth 7 of tree selecting 3/6 attributes: Low,Close,Volume                         Accuracy: 56.00%
# Depth 7 of tree selecting 3/6 attributes: Low,Close,Adjusted                       Accuracy: 44.00%
# Depth 7 of tree selecting 3/6 attributes: Low,Volume,Adjusted                      Accuracy: 50.00%
# Depth 7 of tree selecting 3/6 attributes: Close,Volume,Adjusted                    Accuracy: 50.00%
# Depth 7 of tree selecting 4/6 attributes: Open,High,Low,Close                      Accuracy: 56.00%
# Depth 7 of tree selecting 4/6 attributes: Open,High,Low,Volume                     Accuracy: 56.00%
# Depth 7 of tree selecting 4/6 attributes: Open,High,Low,Adjusted                   Accuracy: 44.00%
# Depth 7 of tree selecting 4/6 attributes: Open,High,Close,Volume                   Accuracy: 56.00%
# Depth 7 of tree selecting 4/6 attributes: Open,High,Close,Adjusted                 Accuracy: 44.00%
# Depth 7 of tree selecting 4/6 attributes: Open,High,Volume,Adjusted                Accuracy: 50.00%
# Depth 7 of tree selecting 4/6 attributes: Open,Low,Close,Volume                    Accuracy: 56.00%
# Depth 7 of tree selecting 4/6 attributes: Open,Low,Close,Adjusted                  Accuracy: 44.00%
# Depth 7 of tree selecting 4/6 attributes: Open,Low,Volume,Adjusted                 Accuracy: 50.00%
# Depth 7 of tree selecting 4/6 attributes: Open,Close,Volume,Adjusted               Accuracy: 50.00%
# Depth 7 of tree selecting 4/6 attributes: High,Low,Close,Volume                    Accuracy: 56.00%
# Depth 7 of tree selecting 4/6 attributes: High,Low,Close,Adjusted                  Accuracy: 44.00%
# Depth 7 of tree selecting 4/6 attributes: High,Low,Volume,Adjusted                 Accuracy: 50.00%
# Depth 7 of tree selecting 4/6 attributes: High,Close,Volume,Adjusted               Accuracy: 50.00%
# Depth 7 of tree selecting 4/6 attributes: Low,Close,Volume,Adjusted                Accuracy: 50.00%
# Depth 7 of tree selecting 5/6 attributes: Open,High,Low,Close,Volume               Accuracy: 56.00%
# Depth 7 of tree selecting 5/6 attributes: Open,High,Low,Close,Adjusted             Accuracy: 44.00%
# Depth 7 of tree selecting 5/6 attributes: Open,High,Low,Volume,Adjusted            Accuracy: 50.00%
# Depth 7 of tree selecting 5/6 attributes: Open,High,Close,Volume,Adjusted          Accuracy: 50.00%
# Depth 7 of tree selecting 5/6 attributes: Open,Low,Close,Volume,Adjusted           Accuracy: 50.00%
# Depth 7 of tree selecting 5/6 attributes: High,Low,Close,Volume,Adjusted           Accuracy: 50.00%
# Depth 7 of tree selecting 6/6 attributes: Open,High,Low,Close,Volume,Adjusted      Accuracy: 50.00%
# Depth 8 of tree selecting 1/6 attributes: Open                                     Accuracy: 56.00%
# Depth 8 of tree selecting 1/6 attributes: High                                     Accuracy: 56.00%
# Depth 8 of tree selecting 1/6 attributes: Low                                      Accuracy: 56.00%
# Depth 8 of tree selecting 1/6 attributes: Close                                    Accuracy: 56.00%
# Depth 8 of tree selecting 1/6 attributes: Volume                                   Accuracy: 56.00%
# Depth 8 of tree selecting 1/6 attributes: Adjusted                                 Accuracy: 44.00%
# Depth 8 of tree selecting 2/6 attributes: Open,High                                Accuracy: 56.00%
# Depth 8 of tree selecting 2/6 attributes: Open,Low                                 Accuracy: 56.00%
# Depth 8 of tree selecting 2/6 attributes: Open,Close                               Accuracy: 56.00%
# Depth 8 of tree selecting 2/6 attributes: Open,Volume                              Accuracy: 56.00%
# Depth 8 of tree selecting 2/6 attributes: Open,Adjusted                            Accuracy: 44.00%
# Depth 8 of tree selecting 2/6 attributes: High,Low                                 Accuracy: 56.00%
# Depth 8 of tree selecting 2/6 attributes: High,Close                               Accuracy: 56.00%
# Depth 8 of tree selecting 2/6 attributes: High,Volume                              Accuracy: 56.00%
# Depth 8 of tree selecting 2/6 attributes: High,Adjusted                            Accuracy: 44.00%
# Depth 8 of tree selecting 2/6 attributes: Low,Close                                Accuracy: 56.00%
# Depth 8 of tree selecting 2/6 attributes: Low,Volume                               Accuracy: 56.00%
# Depth 8 of tree selecting 2/6 attributes: Low,Adjusted                             Accuracy: 44.00%
# Depth 8 of tree selecting 2/6 attributes: Close,Volume                             Accuracy: 56.00%
# Depth 8 of tree selecting 2/6 attributes: Close,Adjusted                           Accuracy: 44.00%
# Depth 8 of tree selecting 2/6 attributes: Volume,Adjusted                          Accuracy: 50.00%
# Depth 8 of tree selecting 3/6 attributes: Open,High,Low                            Accuracy: 56.00%
# Depth 8 of tree selecting 3/6 attributes: Open,High,Close                          Accuracy: 56.00%
# Depth 8 of tree selecting 3/6 attributes: Open,High,Volume                         Accuracy: 56.00%
# Depth 8 of tree selecting 3/6 attributes: Open,High,Adjusted                       Accuracy: 44.00%
# Depth 8 of tree selecting 3/6 attributes: Open,Low,Close                           Accuracy: 56.00%
# Depth 8 of tree selecting 3/6 attributes: Open,Low,Volume                          Accuracy: 56.00%
# Depth 8 of tree selecting 3/6 attributes: Open,Low,Adjusted                        Accuracy: 44.00%
# Depth 8 of tree selecting 3/6 attributes: Open,Close,Volume                        Accuracy: 56.00%
# Depth 8 of tree selecting 3/6 attributes: Open,Close,Adjusted                      Accuracy: 44.00%
# Depth 8 of tree selecting 3/6 attributes: Open,Volume,Adjusted                     Accuracy: 50.00%
# Depth 8 of tree selecting 3/6 attributes: High,Low,Close                           Accuracy: 56.00%
# Depth 8 of tree selecting 3/6 attributes: High,Low,Volume                          Accuracy: 56.00%
# Depth 8 of tree selecting 3/6 attributes: High,Low,Adjusted                        Accuracy: 44.00%
# Depth 8 of tree selecting 3/6 attributes: High,Close,Volume                        Accuracy: 56.00%
# Depth 8 of tree selecting 3/6 attributes: High,Close,Adjusted                      Accuracy: 44.00%
# Depth 8 of tree selecting 3/6 attributes: High,Volume,Adjusted                     Accuracy: 50.00%
# Depth 8 of tree selecting 3/6 attributes: Low,Close,Volume                         Accuracy: 56.00%
# Depth 8 of tree selecting 3/6 attributes: Low,Close,Adjusted                       Accuracy: 44.00%
# Depth 8 of tree selecting 3/6 attributes: Low,Volume,Adjusted                      Accuracy: 50.00%
# Depth 8 of tree selecting 3/6 attributes: Close,Volume,Adjusted                    Accuracy: 50.00%
# Depth 8 of tree selecting 4/6 attributes: Open,High,Low,Close                      Accuracy: 56.00%
# Depth 8 of tree selecting 4/6 attributes: Open,High,Low,Volume                     Accuracy: 56.00%
# Depth 8 of tree selecting 4/6 attributes: Open,High,Low,Adjusted                   Accuracy: 44.00%
# Depth 8 of tree selecting 4/6 attributes: Open,High,Close,Volume                   Accuracy: 56.00%
# Depth 8 of tree selecting 4/6 attributes: Open,High,Close,Adjusted                 Accuracy: 44.00%
# Depth 8 of tree selecting 4/6 attributes: Open,High,Volume,Adjusted                Accuracy: 50.00%
# Depth 8 of tree selecting 4/6 attributes: Open,Low,Close,Volume                    Accuracy: 56.00%
# Depth 8 of tree selecting 4/6 attributes: Open,Low,Close,Adjusted                  Accuracy: 44.00%
# Depth 8 of tree selecting 4/6 attributes: Open,Low,Volume,Adjusted                 Accuracy: 50.00%
# Depth 8 of tree selecting 4/6 attributes: Open,Close,Volume,Adjusted               Accuracy: 50.00%
# Depth 8 of tree selecting 4/6 attributes: High,Low,Close,Volume                    Accuracy: 56.00%
# Depth 8 of tree selecting 4/6 attributes: High,Low,Close,Adjusted                  Accuracy: 44.00%
# Depth 8 of tree selecting 4/6 attributes: High,Low,Volume,Adjusted                 Accuracy: 50.00%
# Depth 8 of tree selecting 4/6 attributes: High,Close,Volume,Adjusted               Accuracy: 50.00%
# Depth 8 of tree selecting 4/6 attributes: Low,Close,Volume,Adjusted                Accuracy: 50.00%
# Depth 8 of tree selecting 5/6 attributes: Open,High,Low,Close,Volume               Accuracy: 56.00%
# Depth 8 of tree selecting 5/6 attributes: Open,High,Low,Close,Adjusted             Accuracy: 44.00%
# Depth 8 of tree selecting 5/6 attributes: Open,High,Low,Volume,Adjusted            Accuracy: 50.00%
# Depth 8 of tree selecting 5/6 attributes: Open,High,Close,Volume,Adjusted          Accuracy: 50.00%
# Depth 8 of tree selecting 5/6 attributes: Open,Low,Close,Volume,Adjusted           Accuracy: 50.00%
# Depth 8 of tree selecting 5/6 attributes: High,Low,Close,Volume,Adjusted           Accuracy: 50.00%
# Depth 8 of tree selecting 6/6 attributes: Open,High,Low,Close,Volume,Adjusted      Accuracy: 50.00%

# %%
print("\nBest accu: {:.2f}% with {} attributes: {} with depth={} of tree"
      .format(best_acc*100, len(best_attributes), best_attributes, best_depth))
# Out:
# Best accu: 56.00% with 1 attributes: ['Open'] with depth=2 of tree

# %% [markdown]
# #### I have tried to improve accuracy by grouping continuous values of all attributes. But the percentage is not improved
